# %%
import pandas as pd

# %%
data = pd.read_excel(r'E:\DIVYANSH\B.Tech\AC_Data.xlsx', parse_dates=[0], index_col=0)

# %%
data.index.names=["Date"]

# %%
data.head()
# Out:
#                          AC 1      AC 2  AC 3  AC 4      AC 5      AC 6  \
# Date
# 2019-08-01 00:00:00  7.518632  8.788315   0.0   0.0  2.617045  4.079041
# 2019-08-01 00:01:00       NaN       NaN   NaN   NaN       NaN       NaN
# 2019-08-01 00:02:00  7.426114  8.940615   0.0   0.0  2.581625  3.781231
# 2019-08-01 00:03:00       NaN       NaN   NaN   NaN       NaN       NaN
# 2019-08-01 00:04:00  7.052986  9.161103   0.0   0.0  2.592095  3.800127
#
#                          AC 7      AC 8      AC 9     AC 10     AC 11  \
# Date
# 2019-08-01 00:00:00  2.782276  4.624447  5.222060  2.151238  1.585072
# 2019-08-01 00:01:00       NaN       NaN       NaN       NaN       NaN
# 2019-08-01 00:02:00  2.529366  5.057423  5.349465  2.414715  2.168184
# 2019-08-01 00:03:00       NaN       NaN       NaN       NaN       NaN
# 2019-08-01 00:04:00  2.332304  6.322521  3.995392  2.237114  3.345624
#
#                         AC 12     AC 13     AC 14     AC 15     AC 16  \
# Date
# ...

# %%
data.shape
# Out:
# (87840, 18)

# %%
data.describe()
# Out:
#                AC 1          AC 2          AC 3          AC 4          AC 5  \
# count  43708.000000  43711.000000  43713.000000  43704.000000  43716.000000
# mean       2.379368      3.868892      2.568411      2.395158      1.421699
# std        2.276782      2.545147      1.487508      1.797529      0.767218
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      2.123263      1.706508      1.258299      0.970744
# 50%        2.094330      3.791752      2.486992      2.308961      1.380183
# 75%        3.661752      5.460892      3.441527      3.476123      1.870234
# max       11.194789     11.147141      8.430909      9.879500      5.495358
#
#                AC 6          AC 7          AC 8          AC 9         AC 10  \
# count  43717.000000  43679.000000  43704.000000  43654.000000  43690.000000
# mean       2.518138      2.980883      2.548711      3.184382      1.538344
# ...

# %%
data.sum()
# Out:
# AC 1     103997.423000
# AC 2     169113.147946
# AC 3     112272.957042
# AC 4     104678.005269
# AC 5      62151.007653
# AC 6     110085.431915
# AC 7     130202.009333
# AC 8     111388.856216
# AC 9     139011.024092
# AC 10     67210.227984
# AC 11    105076.190097
# AC 12    118009.300995
# AC 13    187112.630994
# AC 14    127466.561772
# AC 15    176883.259424
# AC 16    122390.195279
# AC 17    184428.462396
# AC 18    282567.569146
# dtype: float64

# %%
data_dropping_null=data.dropna()

# %%
data_dropping_null.shape
# Out:
# (34642, 18)

# %%
data_dropping_null.describe()
# Out:
#                AC 1          AC 2          AC 3          AC 4          AC 5  \
# count  34642.000000  34642.000000  34642.000000  34642.000000  34642.000000
# mean       2.394089      3.872065      2.504698      2.313283      1.466444
# std        2.309156      2.360155      1.452713      1.705811      0.748515
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      2.272895      1.663072      1.279719      1.008326
# 50%        2.081296      3.738743      2.417197      2.255593      1.408948
# 75%        3.767716      5.334570      3.351791      3.313595      1.903034
# max       11.194789     11.147141      8.430909      9.849144      5.495358
#
#                AC 6          AC 7          AC 8          AC 9         AC 10  \
# count  34642.000000  34642.000000  34642.000000  34642.000000  34642.000000
# mean       2.709061      2.945136      2.568989      3.149919      1.539393
# ...

# %%
data_dropping_null.sum()
# Out:
# AC 1      82936.044911
# AC 2     134136.090605
# AC 3      86767.765132
# AC 4      80136.762231
# AC 5      50800.569898
# AC 6      93847.294549
# AC 7     102025.387626
# AC 8      88994.932128
# AC 9     109119.503611
# AC 10     53327.657137
# AC 11     86125.618895
# AC 12     97550.845176
# AC 13    149411.074408
# AC 14    102438.459866
# AC 15    142868.332861
# AC 16     95809.474174
# AC 17    147405.838816
# AC 18    223573.076079
# dtype: float64

# %% [markdown]
# We can see that data is significantly changed after dropping the null rows. Thus, we can't used data_dropping_null variable.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 87840 entries, 2019-08-01 00:00:00 to 2019-09-30 23:59:00
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AC 1    43708 non-null  float64
#  1   AC 2    43711 non-null  float64
#  2   AC 3    43713 non-null  float64
#  3   AC 4    43704 non-null  float64
#  4   AC 5    43716 non-null  float64
#  5   AC 6    43717 non-null  float64
#  6   AC 7    43679 non-null  float64
#  7   AC 8    43704 non-null  float64
#  8   AC 9    43654 non-null  float64
#  9   AC 10   43690 non-null  float64
#  10  AC 11   43670 non-null  float64
#  11  AC 12   43713 non-null  float64
#  12  AC 13   43719 non-null  float64
#  13  AC 14   43696 non-null  float64
#  14  AC 15   43715 non-null  float64
#  15  AC 16   43710 non-null  float64
#  16  AC 17   43714 non-null  float64
#  17  AC 18   43723 non-null  float64
# dtypes: float64(18)
# memory usage: 12.7 MB

# %%
data.corr()
# Out:
#            AC 1      AC 2      AC 3      AC 4      AC 5      AC 6      AC 7  \
# AC 1   1.000000  0.430097  0.236607  0.328553  0.100152  0.225852  0.031081
# AC 2   0.430097  1.000000  0.250247  0.436843  0.109168  0.208857  0.048340
# AC 3   0.236607  0.250247  1.000000  0.264392  0.062186  0.093411  0.027422
# AC 4   0.328553  0.436843  0.264392  1.000000  0.141945  0.180688  0.086190
# AC 5   0.100152  0.109168  0.062186  0.141945  1.000000  0.262816  0.111106
# AC 6   0.225852  0.208857  0.093411  0.180688  0.262816  1.000000  0.189372
# AC 7   0.031081  0.048340  0.027422  0.086190  0.111106  0.189372  1.000000
# AC 8   0.104567  0.075229  0.113742  0.160474  0.118360  0.201005  0.206060
# AC 9   0.108839  0.147773  0.131613  0.173537  0.119612  0.184327  0.180162
# AC 10  0.189108  0.160593  0.072995  0.165599  0.109955  0.184588  0.202509
# AC 11  0.312637  0.186961  0.145109  0.133118  0.134732  0.267939  0.166265
# ...

# %%
df1a=data.loc["2019-08-01"]

# %%
df1a
# Out:
#                          AC 1      AC 2      AC 3      AC 4      AC 5  \
# Date
# 2019-08-01 00:00:00  7.518632  8.788315  0.000000  0.000000  2.617045
# 2019-08-01 00:01:00       NaN       NaN       NaN       NaN       NaN
# 2019-08-01 00:02:00  7.426114  8.940615  0.000000  0.000000  2.581625
# 2019-08-01 00:03:00       NaN       NaN       NaN       NaN       NaN
# 2019-08-01 00:04:00  7.052986  9.161103  0.000000  0.000000  2.592095
# ...                       ...       ...       ...       ...       ...
# 2019-08-01 23:55:00       NaN       NaN       NaN       NaN       NaN
# 2019-08-01 23:56:00  7.022365  9.361391  3.381782  4.628641  1.284231
# 2019-08-01 23:57:00       NaN       NaN       NaN       NaN       NaN
# 2019-08-01 23:58:00  6.862105  9.409969  2.753045  5.166084  1.120495
# 2019-08-01 23:59:00       NaN       NaN       NaN       NaN       NaN
#
#                          AC 6      AC 7      AC 8      AC 9     AC 10  \
# Date
# ...
